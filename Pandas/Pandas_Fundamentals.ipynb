# %% [markdown]
#  1. Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Pandas Lesson #1
# Content to cover
# 1. Loading and reading data... read different file extensions, reading from urls
# 2. Go over basic inspections of a dataframe... head, tail, shape, describe, columns
# 3. Working with subsets of a dataframe-loc &iloc
# 4. Filtering dataframes based on a specific criteria
# 5. Changing the order of columns, renaming columns, adding new columns

# %% [markdown]
#  2. Loading & Reading Data

# %%
data=pd.read_csv('Sales.csv')
data
# Out:
#        Brands          Models         Colors Memory                Storage  \
# 0     SAMSUNG    GALAXY M31S    Mirage Black   8 GB                 128 GB
# 1       Nokia             3.2          Steel   2 GB                  16 GB
# 2      realme             C2   Diamond Black   2 GB                    NaN
# 3     Infinix          Note 5       Ice Blue   4 GB                  64 GB
# 4       Apple      iPhone 11           Black    4GB                  64 GB
# ...       ...             ...            ...    ...                    ...
# 3109     POCO       M4 Pro 5G      Cool Blue   6 GB                 128 GB
# 3110    Nokia             225          Black    NaN  Expandable Upto 32 GB
# 3111    Apple      iPhone SE           White   2 GB                 128 GB
# 3112    Apple  iPhone 13 Pro            Gold   6 GB                 128 GB
# 3113   GIONEE             F9            Blue   3 GB                  32 GB
#
# ...

# %%
data2=pd.read_csv('file.tsv',sep='\t')
data2.head()
# Out:
#      0   50  5  881250949
# 0    0  172  5  881250949
# 1    0  133  1  881250949
# 2  196  242  3  881250949
# 3  186  302  3  891717742
# 4   22  377  1  878887116

# %%
data3=pd.read_excel(r"C:\Users\Pula Advisors\Desktop\CDR_Data\CCE_Data_Clean.xlsx")
data.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# 4             0.000000

# %%
# Webpage URL
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

iris_data = pd.read_csv(url)

iris_data.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# # 2. Basic Inspection of a dataframe

# %%
data.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# 4             0.000000

# %%
data.tail()
# Out:
#       Brands          Models     Colors Memory                Storage Camera  \
# 3109    POCO       M4 Pro 5G  Cool Blue   6 GB                 128 GB    Yes
# 3110   Nokia             225      Black    NaN  Expandable Upto 32 GB    Yes
# 3111   Apple      iPhone SE       White   2 GB                 128 GB    Yes
# 3112   Apple  iPhone 13 Pro        Gold   6 GB                 128 GB    Yes
# 3113  GIONEE             F9        Blue   3 GB                  32 GB    Yes
#
#       Rating  Selling Price  Original Price                Mobile  Discount  \
# 3109     4.4          16999           19999        POCO M4 Pro 5G      3000
# 3110     3.6           3499            3499             Nokia 225         0
# 3111     4.5          44900           44900      Apple iPhone SE          0
# 3112     NaN         119900          119900  Apple iPhone 13 Pro          0
# 3113     4.2           7900            7900            GIONEE F9          0
#
#       discount percentage
# ...

# %%
data.describe()
# Out:
#             Rating  Selling Price  Original Price      Discount  \
# count  2970.000000    3114.000000     3114.000000   3114.000000
# mean      4.243098   26436.625562    28333.473025   1896.847463
# std       0.271991   30066.892622    31525.599889   5337.126176
# min       2.300000    1000.000000     1000.000000  -8000.000000
# 25%       4.100000    9990.000000    10030.250000      0.000000
# 50%       4.300000   15000.000000    16889.500000      0.000000
# 75%       4.400000   28999.000000    31500.000000   2000.000000
# max       5.000000  179900.000000   189999.000000  75000.000000
#
#        discount percentage
# count          3114.000000
# mean              6.086788
# std              11.106776
# min            -160.320641
# 25%               0.000000
# 50%               0.000000
# 75%               9.836388
# max              70.610305

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3114 entries, 0 to 3113
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brands               3114 non-null   object
#  1   Models               3114 non-null   object
#  2   Colors               3114 non-null   object
#  3   Memory               3071 non-null   object
#  4   Storage              3075 non-null   object
#  5   Camera               3114 non-null   object
#  6   Rating               2970 non-null   float64
#  7   Selling Price        3114 non-null   int64
#  8   Original Price       3114 non-null   int64
#  9   Mobile               3114 non-null   object
#  10  Discount             3114 non-null   int64
#  11  discount percentage  3114 non-null   float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 292.1+ KB

# %%
data.columns
# Out:
# Index(['Brands', 'Models', 'Colors', 'Memory', 'Storage', 'Camera', 'Rating',
#        'Selling Price', 'Original Price', 'Mobile', 'Discount',
#        'discount percentage'],
#       dtype='object')

# %%
data.shape
# Out:
# (3114, 12)

# %% [markdown]
# # Accessing specific columns in a dataframe

# %%
data.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# 4             0.000000

# %%
data.iloc[0]
# Out:
# Brands                              SAMSUNG
# Models                         GALAXY M31S
# Colors                         Mirage Black
# Memory                                 8 GB
# Storage                              128 GB
# Camera                                  Yes
# Rating                                  4.3
# Selling Price                         19330
# Original Price                        20999
# Mobile                 SAMSUNG GALAXY M31S
# Discount                               1669
# discount percentage                7.947998
# Name: 0, dtype: object

# %%
data.iloc[[1,20,35]]
# Out:
#       Brands             Models Colors  Memory Storage Camera  Rating  \
# 1      Nokia                3.2  Steel    2 GB   16 GB    Yes     3.8
# 20  Motorola                  M   Grey    4 GB   64 GB    Yes     3.9
# 35   SAMSUNG  Galaxy J2 - 2016    Gold  1.5 GB    8 GB    Yes     4.0
#
#     Selling Price  Original Price                     Mobile  Discount  \
# 1           10199           10199                  Nokia 3.2         0
# 20           9999            9999                 Motorola M         0
# 35           6990            6990  SAMSUNG Galaxy J2 - 2016          0
#
#     discount percentage
# 1                   0.0
# 20                  0.0
# 35                  0.0

# %%
data.iloc[0:20:2]
# Out:
#      Brands           Models         Colors  Memory Storage Camera  Rating  \
# 0   SAMSUNG     GALAXY M31S    Mirage Black    8 GB  128 GB    Yes     4.3
# 2    realme              C2   Diamond Black    2 GB     NaN    Yes     4.4
# 4     Apple       iPhone 11           Black     4GB   64 GB    Yes     4.6
# 6     Apple  iPhone 13 Mini            Pink    6 GB  512 GB    Yes     NaN
# 8   SAMSUNG       Galaxy E5           Brown  1.5 GB   16 GB    Yes     4.2
# 10  SAMSUNG      Galaxy A12           Black    4 GB   64 GB    Yes     4.2
# 12   realme           X7 5G          Nebula    6 GB  128 GB    Yes     4.3
# 14     vivo           V23 5G  Sunshine Gold    8 GB  128 GB    Yes     4.4
# 16    Apple  iPhone 13 Mini            Pink    6 GB  512 GB    Yes     NaN
# 18   Lenovo        K10 Plus          Sprite    4 GB   64 GB    Yes     4.1
#
#     Selling Price  Original Price                 Mobile  Discount  \
# 0           19330           20999   SAMSUNG GALAXY M31S       1669
# ...

# %%
#df.loc[row,column]
#.loc selects data using row and column names (labels), while .iloc uses numerical indices (positions).
#selecting a single row
#selecting multiple rows
data.iloc[[0,20]]
# Out:
#       Brands        Models        Colors Memory Storage Camera  Rating  \
# 0    SAMSUNG  GALAXY M31S   Mirage Black   8 GB  128 GB    Yes     4.3
# 20  Motorola             M          Grey   4 GB   64 GB    Yes     3.9
#
#     Selling Price  Original Price                Mobile  Discount  \
# 0           19330           20999  SAMSUNG GALAXY M31S       1669
# 20           9999            9999            Motorola M         0
#
#     discount percentage
# 0              7.947998
# 20             0.000000

# %%
data.iloc[0:20].head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# 4             0.000000

# %%
data.iloc[:,0].nunique()
# Out:
# 17

# %%
data.iloc[: , [0,3]].head()
# Out:
#     Brands Memory
# 0  SAMSUNG   8 GB
# 1    Nokia   2 GB
# 2   realme   2 GB
# 3  Infinix   4 GB
# 4    Apple    4GB

# %%
data.iloc[:,0:4]
# Out:
#        Brands          Models         Colors Memory
# 0     SAMSUNG    GALAXY M31S    Mirage Black   8 GB
# 1       Nokia             3.2          Steel   2 GB
# 2      realme             C2   Diamond Black   2 GB
# 3     Infinix          Note 5       Ice Blue   4 GB
# 4       Apple      iPhone 11           Black    4GB
# ...       ...             ...            ...    ...
# 3109     POCO       M4 Pro 5G      Cool Blue   6 GB
# 3110    Nokia             225          Black    NaN
# 3111    Apple      iPhone SE           White   2 GB
# 3112    Apple  iPhone 13 Pro            Gold   6 GB
# 3113   GIONEE             F9            Blue   3 GB
#
# [3114 rows x 4 columns]

# %%
data.iloc[:,9].value_counts().head()
# Out:
# Mobile
# Apple iPhone 11         36
# Apple iPhone XR         27
# Apple iPhone 7          22
# Apple iPhone 11 Pro     21
# Apple iPhone 7 Plus     20
# Name: count, dtype: int64

# %% [markdown]
# # Let's get our hands dirty!
# 1. How many mobile brands are featured in the dataset?
# 2. What is the most expensive mobile phone in the dataset?
# 3. What is the cheapest mobile phone in the dataset?
# 4. Which is the most popular mobile phone? Selling hot!

# %%
data.iloc[:,0].nunique()
# Out:
# 17

# %%
data.iloc[data.iloc[:,7].idxmax()]
# Out:
# Brands                                    Apple
# Models                       iPhone 13 Pro Max
# Colors                                     Gold
# Memory                                     6 GB
# Storage                                    1 TB
# Camera                                      Yes
# Rating                                      NaN
# Selling Price                            179900
# Original Price                           179900
# Mobile                 Apple iPhone 13 Pro Max
# Discount                                      0
# discount percentage                         0.0
# Name: 323, dtype: object

# %% [markdown]
# # loc method

# %%
df=data.iloc[0:26,:]
df.shape
# Out:
# (26, 12)

# %%
#to illustrate the loc method properly, 
# lets change the index to a string value, so you appreciate the difference
import string
letters=list(string.ascii_uppercase)

# %%
df.index=letters
df.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# A  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# B    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# C   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# D  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# E    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# A          19330           20999  SAMSUNG GALAXY M31S       1669
# B          10199           10199             Nokia 3.2         0
# C           6999            7999            realme C2       1000
# D          12999           12999        Infinix Note 5         0
# E          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# A             7.947998
# B             0.000000
# C            12.501563
# D             0.000000
# E             0.000000

# %%
df.loc['A':'H']
# Out:
#     Brands           Models         Colors Memory Storage Camera  Rating  \
# A  SAMSUNG     GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# B    Nokia              3.2          Steel   2 GB   16 GB    Yes     3.8
# C   realme              C2   Diamond Black   2 GB     NaN    Yes     4.4
# D  Infinix           Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# E    Apple       iPhone 11           Black    4GB   64 GB    Yes     4.6
# F   GIONEE             L800          Black   8 MB   16 MB    Yes     4.0
# G    Apple  iPhone 13 Mini            Pink   6 GB  512 GB    Yes     NaN
# H    Apple       iPhone XR           Coral   3 GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                 Mobile  Discount  \
# A          19330           20999   SAMSUNG GALAXY M31S       1669
# B          10199           10199              Nokia 3.2         0
# C           6999            7999             realme C2       1000
# ...

# %%
df.loc['A':'G','Models':'Rating']
# Out:
#             Models         Colors Memory Storage Camera  Rating
# A     GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# B              3.2          Steel   2 GB   16 GB    Yes     3.8
# C              C2   Diamond Black   2 GB     NaN    Yes     4.4
# D           Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# E       iPhone 11           Black    4GB   64 GB    Yes     4.6
# F             L800          Black   8 MB   16 MB    Yes     4.0
# G  iPhone 13 Mini            Pink   6 GB  512 GB    Yes     NaN

# %%
df.loc[:,'Brands'].nunique()
# Out:
# 12

# %%
df.loc[:,'Selling Price'].idxmax()
# Out:
# 'G'

# %%
df.loc[:,'Mobile'].value_counts()
# Out:
# Mobile
# Apple iPhone 13 Mini        2
# Apple iPhone 11             2
# SAMSUNG GALAXY M31S         1
# Nokia 3.2                   1
# Infinix Note 5              1
# realme C2                   1
# GIONEE L800                 1
# Apple iPhone XR             1
# SAMSUNG Galaxy E5           1
# Xiaomi Redmi Note 11T 5G    1
# SAMSUNG Galaxy A12          1
# realme X7 5G                1
# OPPO A33                    1
# vivo V23 5G                 1
# vivo Y20A 2021              1
# SAMSUNG Galaxy J2 Core      1
# Lenovo K10 Plus             1
# ASUS Zenfone Max            1
# Motorola M                  1
# realme 1                    1
# GIONEE Pioneer P4S          1
# realme X3                   1
# realme Narzo 30A            1
# realme 8 Pro                1
# Name: count, dtype: int64

# %%
#renaming columns
data.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# 4             0.000000

# %%
data.rename(columns={'Brands':'Mobile_Brand'},inplace=True)
data.head()
# Out:
#   Mobile_Brand        Models         Colors Memory Storage Camera  Rating  \
# 0      SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1        Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2       realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3      Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4        Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# ...

# %% [markdown]
# ## Filtering Dataframe based on a criteria

# %%
data.loc[(data['Brands']=='SAMSUNG') & (data['Selling Price']>20000)]
# Out:
#        Brands             Models            Colors  Memory Storage Camera  \
# 8     SAMSUNG         Galaxy E5              Brown  1.5 GB   16 GB    Yes
# 28    SAMSUNG    Galaxy S9 Plus       Polaris Blue    6 GB   64 GB    Yes
# 32    SAMSUNG     Galaxy Note 9     Midnight Black    8 GB  512 GB    Yes
# 44    SAMSUNG     Galaxy A22 5G             Violet    8 GB  128 GB    Yes
# 47    SAMSUNG     Galaxy A9 Pro              Black    4 GB   32 GB    Yes
# ...       ...                ...               ...     ...     ...    ...
# 3058  SAMSUNG        Galaxy A80      Phantom Black    8 GB  128 GB    Yes
# 3069  SAMSUNG        Galaxy A51   Prism Crush Blue    8 GB  128 GB    Yes
# 3072  SAMSUNG    Galaxy S9 Plus     Midnight Black    6 GB  128 GB    Yes
# 3099  SAMSUNG     Galaxy Fold 2      Mystic Bronze   12 GB  256 GB    Yes
# 3102  SAMSUNG  Galaxy S20 Ultra       Cosmic Black   12 GB  128 GB    Yes
#
#       Rating  Selling Price  Original Price                     Mobile  \
# ...

# %%
data['Brands']=='SAMSUNG'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3109    False
# 3110    False
# 3111    False
# 3112    False
# 3113    False
# Name: Brands, Length: 3114, dtype: bool

# %%
data[data['Brands']=='SAMSUNG']
# Out:
#        Brands              Models         Colors  Memory Storage Camera  \
# 0     SAMSUNG        GALAXY M31S    Mirage Black    8 GB  128 GB    Yes
# 8     SAMSUNG          Galaxy E5           Brown  1.5 GB   16 GB    Yes
# 10    SAMSUNG         Galaxy A12           Black    4 GB   64 GB    Yes
# 17    SAMSUNG     Galaxy J2 Core            Gold    1 GB   16 GB    Yes
# 28    SAMSUNG     Galaxy S9 Plus    Polaris Blue    6 GB   64 GB    Yes
# ...       ...                 ...            ...     ...     ...    ...
# 3096  SAMSUNG  Metro 313 Dual Sim          Black    4 MB    2 MB    Yes
# 3099  SAMSUNG      Galaxy Fold 2   Mystic Bronze   12 GB  256 GB    Yes
# 3102  SAMSUNG   Galaxy S20 Ultra    Cosmic Black   12 GB  128 GB    Yes
# 3107  SAMSUNG    Galaxy S Duos 2           Black  512 MB    4 GB    Yes
# 3108  SAMSUNG           Metro 313          Black    4 MB    2 MB    Yes
#
#       Rating  Selling Price  Original Price                      Mobile  \
# ...

# %% [markdown]
#  # 4. Handling missing data

# %%
#checking for missing data
data.isnull()
# Out:
#       Mobile_Brand  Models  Colors  Memory  Storage  Camera  Rating  \
# 0            False   False   False   False    False   False   False
# 1            False   False   False   False    False   False   False
# 2            False   False   False   False     True   False   False
# 3            False   False   False   False    False   False   False
# 4            False   False   False   False    False   False   False
# ...            ...     ...     ...     ...      ...     ...     ...
# 3109         False   False   False   False    False   False   False
# 3110         False   False   False    True    False   False   False
# 3111         False   False   False   False    False   False   False
# 3112         False   False   False   False    False   False    True
# 3113         False   False   False   False    False   False   False
#
#       Selling Price  Original Price  Mobile  Discount  discount percentage
# 0             False           False   False     False                False
# ...

# %%
boolean_series=data.isnull()
missing_data=data[boolean_series]
missing_data
# Out:
#      Mobile_Brand Models Colors Memory Storage Camera  Rating  Selling Price  \
# 0             NaN    NaN    NaN    NaN     NaN    NaN     NaN            NaN
# 1             NaN    NaN    NaN    NaN     NaN    NaN     NaN            NaN
# 2             NaN    NaN    NaN    NaN     NaN    NaN     NaN            NaN
# 3             NaN    NaN    NaN    NaN     NaN    NaN     NaN            NaN
# 4             NaN    NaN    NaN    NaN     NaN    NaN     NaN            NaN
# ...           ...    ...    ...    ...     ...    ...     ...            ...
# 3109          NaN    NaN    NaN    NaN     NaN    NaN     NaN            NaN
# 3110          NaN    NaN    NaN    NaN     NaN    NaN     NaN            NaN
# 3111          NaN    NaN    NaN    NaN     NaN    NaN     NaN            NaN
# 3112          NaN    NaN    NaN    NaN     NaN    NaN     NaN            NaN
# 3113          NaN    NaN    NaN    NaN     NaN    NaN     NaN            NaN
#
# ...

# %%
data.isnull().sum()
# Out:
# Mobile_Brand             0
# Models                   0
# Colors                   0
# Memory                  43
# Storage                 39
# Camera                   0
# Rating                 144
# Selling Price            0
# Original Price           0
# Mobile                   0
# Discount                 0
# discount percentage      0
# dtype: int64

# %%
total_missing=data.isnull().sum()
all_data=data.isnull().count()
percent_missing=total_missing/all_data
percent_missing
# Out:
# Mobile_Brand           0.000000
# Models                 0.000000
# Colors                 0.000000
# Memory                 0.013809
# Storage                0.012524
# Camera                 0.000000
# Rating                 0.046243
# Selling Price          0.000000
# Original Price         0.000000
# Mobile                 0.000000
# Discount               0.000000
# discount percentage    0.000000
# dtype: float64

# %%
import missingno as mn
mn.matrix(data)
# Out:
# <Axes: >

# %%
#Handing missingness by dropping missing rows/columns
data.dropna(axis=1)
data.shape
# Out:
# (2897, 12)

# %%
#handling missingness with imputation

# %% [markdown]
# # Aggregation & Grouping

# %%
data.head()
# Out:
#   Mobile_Brand        Models        Colors Memory Storage Camera  Rating  \
# 0      SAMSUNG  GALAXY M31S   Mirage Black   8 GB  128 GB    Yes     4.3
# 1        Nokia           3.2         Steel   2 GB   16 GB    Yes     3.8
# 3      Infinix        Note 5      Ice Blue   4 GB   64 GB    Yes     4.2
# 4        Apple    iPhone 11          Black    4GB   64 GB    Yes     4.6
# 5       GIONEE          L800         Black   8 MB   16 MB    Yes     4.0
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
# 5           2199            2199           GIONEE L800         0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 3             0.000000
# 4             0.000000
# ...

# %%
data.groupby(['Memory','Storage'])['Selling Price'].mean()
# Out:
# Memory  Storage
# 1 GB    128 GB                   64499.600000
#         16 GB                    12411.120690
#         32 GB                    34086.333333
#         4 GB                     13542.230769
#         64 GB                    57356.714286
#                                      ...
# 8 GB    256 GB                   41676.944444
#         512 GB                   68985.142857
# 8 MB    16 MB                     2236.428571
#         2 MB                      2999.000000
#         Expandable Upto 32 GB     2849.500000
# Name: Selling Price, Length: 81, dtype: float64

# %%
data.pivot_table()

# %%
import pandas as pd

# Create a pivot table
pivot_avg_price = pd.pivot_table(
    data,
    values='Selling Price',
    index='Mobile_Brand',  # Rows: each brand
    columns='Colors',           # Columns: different colours
    aggfunc='mean',             # Calculate the average
    fill_value=0                # Replace NaNs with 0 if no data is available
)

pivot_avg_price
# Out:
# Colors         Tornado Black  AURORA SILVER  Absolute black  Aegean Blue  \
# Mobile_Brand
# ASUS                     0.0            0.0             0.0          0.0
# Apple                    0.0            0.0             0.0          0.0
# GIONEE                   0.0            0.0             0.0          0.0
# Google Pixel             0.0            0.0             0.0          0.0
# HTC                      0.0            0.0             0.0          0.0
# IQOO                 39990.0            0.0             0.0          0.0
# Infinix                  0.0            0.0             0.0       8149.0
# LG                       0.0        29999.0             0.0          0.0
# Lenovo                   0.0            0.0             0.0          0.0
# Motorola                 0.0            0.0             0.0          0.0
# Nokia                    0.0            0.0             0.0          0.0
# OPPO                     0.0            0.0             0.0          0.0
# ...

# %%
data['Selling Price'].mean()
# Out:
# np.float64(24692.49223334484)

# %%
#which brand has been given the highest discount
data.groupby('Mobile_Brand')['Discount'].mean().sort_values(ascending=False)
# Out:
# Mobile_Brand
# Motorola        4349.601942
# IQOO            3800.000000
# Apple           3556.774295
# LG              3075.663265
# POCO            2650.684932
# SAMSUNG         2644.413139
# OPPO            2004.860558
# vivo            1459.526316
# realme          1415.480427
# ASUS             959.459459
# Infinix          925.907285
# Xiaomi           897.109948
# Nokia            863.266304
# GIONEE           694.283465
# Google Pixel     620.344828
# Lenovo           268.891667
# HTC                0.000000
# Name: Discount, dtype: float64

# %%
data.groupby('Mobile_Brand')['Models'].nunique().sort_values(ascending=False)
# Out:
# Mobile_Brand
# SAMSUNG         196
# Nokia            78
# OPPO             74
# LG               63
# realme           61
# GIONEE           60
# vivo             58
# Lenovo           54
# Motorola         50
# Xiaomi           49
# Infinix          41
# ASUS             29
# HTC              29
# Apple            23
# POCO             14
# Google Pixel     11
# IQOO              1
# Name: Models, dtype: int64

# %%
data.groupby('Mobile_Brand')['Models'].nunique()
# Out:
# Mobile_Brand
# ASUS             29
# Apple            23
# GIONEE           60
# Google Pixel     11
# HTC              29
# IQOO              1
# Infinix          41
# LG               63
# Lenovo           54
# Motorola         50
# Nokia            78
# OPPO             74
# POCO             14
# SAMSUNG         196
# Xiaomi           49
# realme           61
# vivo             58
# Name: Models, dtype: int64

# %%
# Group by mobile_brand_name and calculate the selling price range for each brand
price_range = data.groupby('Mobile_Brand')['Selling Price'].agg(lambda x: x.max() - x.min())

# Print the result
print(price_range)
# Out:
# Mobile_Brand
# ASUS             58500
# Apple           154901
# GIONEE           20400
# Google Pixel     80000
# HTC              55991
# IQOO              5000
# Infinix          13050
# LG               55000
# Lenovo           26450
# Motorola         84549
# Nokia            55299
# OPPO             55991
# POCO             23000
# SAMSUNG         156549
# Xiaomi           48500
# realme           41500
# vivo             72000
# Name: Selling Price, dtype: int64

# %%
data.groupby('Mobile_Brand')[['Memory','Storage']].max()
# Out:
#              Memory                Storage
# Mobile_Brand
# ASUS           8 GB                   8 GB
# Apple          6 GB                  64 GB
# GIONEE         8 MB                   8 GB
# Google Pixel   6 GB                  64 GB
# HTC            6 GB                   8 GB
# IQOO           8 GB                 256 GB
# Infinix        8 GB                  64 GB
# LG             8 GB                   8 GB
# Lenovo         6 GB                   8 GB
# Motorola       8 GB                   8 GB
# Nokia          8 MB  Expandable Upto 32 GB
# OPPO           8 GB                  64 GB
# POCO           8 GB                  64 GB
# SAMSUNG        8 GB  Expandable Upto 16 GB
# Xiaomi         8 GB                  64 GB
# realme         8 GB                  64 GB
# vivo           8 GB                  64 GB

# %%
data.groupby('Mobile_Brand')[['Selling Price','Discount']].mean()
# Out:
#               Selling Price     Discount
# Mobile_Brand
# ASUS           17590.837838   959.459459
# Apple          73340.479624  3556.774295
# GIONEE          7112.181102   694.283465
# Google Pixel   61391.862069   620.344828
# HTC            28314.381818     0.000000
# IQOO           37190.000000  3800.000000
# Infinix        11092.178808   925.907285
# LG             19214.244898  3075.663265
# Lenovo         10055.458333   268.891667
# Motorola       16228.504854  4349.601942
# Nokia           9994.760870   863.266304
# OPPO           18485.812749  2004.860558
# POCO           16759.273973  2650.684932
# SAMSUNG        24817.503650  2644.413139
# Xiaomi         16935.209424   897.109948
# realme         16734.750890  1415.480427
# vivo           23539.596491  1459.526316

# %%
null_data = data[data.isnull().any(axis=1)]
null_data
# Out:
#      Mobile_Brand              Models         Colors Memory  \
# 2          realme                 C2   Diamond Black   2 GB
# 6           Apple     iPhone 13 Mini            Pink   6 GB
# 15           vivo          Y20A 2021     Nebula Blue    NaN
# 16          Apple     iPhone 13 Mini            Pink   6 GB
# 21         realme                   1  Diamond Black   3 GB
# ...           ...                 ...            ...    ...
# 3090        Apple          iPhone 13            Blue    4GB
# 3105        Apple  iPhone 13 Pro Max            Gold   6 GB
# 3106         ASUS    ROG Phone 5 Pro           Black  16 GB
# 3110        Nokia                 225          Black    NaN
# 3112        Apple      iPhone 13 Pro            Gold   6 GB
#
#                     Storage Camera  Rating  Selling Price  Original Price  \
# 2                       NaN    Yes     4.4           6999            7999
# 6                    512 GB    Yes     NaN          99900           99900
# ...

# %%
data.isnull()
# Out:
#       Brands  Models  Colors  Memory  Storage  Camera  Rating  Selling Price  \
# 0      False   False   False   False    False   False   False          False
# 1      False   False   False   False    False   False   False          False
# 2      False   False   False   False     True   False   False          False
# 3      False   False   False   False    False   False   False          False
# 4      False   False   False   False    False   False   False          False
# ...      ...     ...     ...     ...      ...     ...     ...            ...
# 3109   False   False   False   False    False   False   False          False
# 3110   False   False   False    True    False   False   False          False
# 3111   False   False   False   False    False   False   False          False
# 3112   False   False   False   False    False   False    True          False
# 3113   False   False   False   False    False   False   False          False
#
# ...

# %%
data.notnull()
# Out:
#       Brands  Models  Colors  Memory  Storage  Camera  Rating  Selling Price  \
# 0       True    True    True    True     True    True    True           True
# 1       True    True    True    True     True    True    True           True
# 2       True    True    True    True    False    True    True           True
# 3       True    True    True    True     True    True    True           True
# 4       True    True    True    True     True    True    True           True
# ...      ...     ...     ...     ...      ...     ...     ...            ...
# 3109    True    True    True    True     True    True    True           True
# 3110    True    True    True   False     True    True    True           True
# 3111    True    True    True    True     True    True    True           True
# 3112    True    True    True    True     True    True   False           True
# 3113    True    True    True    True     True    True    True           True
#
# ...

# %%
# !pip install missingno
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import missingno as mn
mn.matrix(data)
# Out:
# <Axes: >

# %%
data[['Brands','Models','Colors']]
# Out:
#        Brands          Models         Colors
# 0     SAMSUNG    GALAXY M31S    Mirage Black
# 1       Nokia             3.2          Steel
# 2      realme             C2   Diamond Black
# 3     Infinix          Note 5       Ice Blue
# 4       Apple      iPhone 11           Black
# ...       ...             ...            ...
# 3109     POCO       M4 Pro 5G      Cool Blue
# 3110    Nokia             225          Black
# 3111    Apple      iPhone SE           White
# 3112    Apple  iPhone 13 Pro            Gold
# 3113   GIONEE             F9            Blue
#
# [3114 rows x 3 columns]

# %%
data.loc[0]
# Out:
# Brands                              SAMSUNG
# Models                         GALAXY M31S
# Colors                         Mirage Black
# Memory                                 8 GB
# Storage                              128 GB
# Camera                                  Yes
# Rating                                  4.3
# Selling Price                         19330
# Original Price                        20999
# Mobile                 SAMSUNG GALAXY M31S
# Discount                               1669
# discount percentage                7.947998
# Name: 0, dtype: object

# %% [markdown]
#  5. Selecting & Accessing data on the dataframe

# %%
data.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# 4             0.000000

# %%
data.iloc[:,1:6]
# Out:
#               Models         Colors Memory                Storage Camera
# 0       GALAXY M31S    Mirage Black   8 GB                 128 GB    Yes
# 1                3.2          Steel   2 GB                  16 GB    Yes
# 2                C2   Diamond Black   2 GB                    NaN    Yes
# 3             Note 5       Ice Blue   4 GB                  64 GB    Yes
# 4         iPhone 11           Black    4GB                  64 GB    Yes
# ...              ...            ...    ...                    ...    ...
# 3109       M4 Pro 5G      Cool Blue   6 GB                 128 GB    Yes
# 3110             225          Black    NaN  Expandable Upto 32 GB    Yes
# 3111      iPhone SE           White   2 GB                 128 GB    Yes
# 3112  iPhone 13 Pro            Gold   6 GB                 128 GB    Yes
# 3113             F9            Blue   3 GB                  32 GB    Yes
#
# [3114 rows x 5 columns]

# %%
data.loc[(data['Selling Price']>10000) & (data['Storage']=='64 GB')]
# Out:
#         Brands           Models         Colors Memory Storage Camera  Rating  \
# 3      Infinix           Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4        Apple       iPhone 11           Black    4GB   64 GB    Yes     4.6
# 7        Apple       iPhone XR           Coral   3 GB   64 GB    Yes     4.6
# 10     SAMSUNG      Galaxy A12           Black   4 GB   64 GB    Yes     4.2
# 15        vivo       Y20A 2021     Nebula Blue    NaN   64 GB    Yes     3.8
# ...        ...              ...            ...    ...     ...    ...     ...
# 3085   Infinix           S5 Pro       Sea Blue   4 GB   64 GB    Yes     4.4
# 3087  Motorola       G10 Power     Aurora Grey   4 GB   64 GB    Yes     4.1
# 3089      ASUS  ZenFone Max M2            Blue   4 GB   64 GB    Yes     4.3
# 3098    realme                2  Diamond Black   4 GB   64 GB    Yes     4.4
# 3103     Apple        iPhone X      Space Gray   3 GB   64 GB    Yes     4.6
#
# ...

# %%
data.loc[data['Memory']=='8 GB']
# Out:
#        Brands                      Models            Colors Memory Storage  \
# 0     SAMSUNG                GALAXY M31S       Mirage Black   8 GB  128 GB
# 9      Xiaomi           Redmi Note 11T 5G   Aquamarine Blue   8 GB  128 GB
# 14       vivo                      V23 5G     Sunshine Gold   8 GB  128 GB
# 32    SAMSUNG              Galaxy Note 9     Midnight Black   8 GB  512 GB
# 38     realme               X3 SuperZoom       Arctic White   8 GB     NaN
# ...       ...                         ...               ...    ...     ...
# 3058  SAMSUNG                 Galaxy A80      Phantom Black   8 GB  128 GB
# 3059     OPPO                       Reno2        Ocean Blue   8 GB  256 GB
# 3066  Infinix  Note 11S Free Fire Edition        Haze Green   8 GB  128 GB
# 3069  SAMSUNG                 Galaxy A51   Prism Crush Blue   8 GB  128 GB
# 3073   realme            Narzo 30 Pro 5G       Blade Silver   8 GB  128 GB
#
#      Camera  Rating  Selling Price  Original Price  \
# ...

# %% [markdown]
#  6. Adding & Removing Data

# %% [markdown]
#  7. Grouping & Aggregation

# %%
df=pd.read_csv(r"C:\Users\Pula Advisors\Desktop\PyData_Class\datasets\car_prices.csv")
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
best_seller=df.groupby(['make','year'])['sellingprice'].max()
best_seller.head()
# Out:
# make   year
# Acura  1993     500.0
#        1994    1800.0
#        1995     850.0
#        1996    1800.0
#        1997    2900.0
# Name: sellingprice, dtype: float64

# %%
sales_per_year=df.groupby('year')['sellingprice'].count()
sales_per_year
# Out:
# year
# 1982         2
# 1983         1
# 1984         5
# 1985        10
# 1986        11
# 1987         8
# 1988        11
# 1989        20
# 1990        49
# 1991        67
# 1992       132
# 1993       205
# 1994       392
# 1995       711
# 1996       851
# 1997      1546
# 1998      2149
# 1999      3363
# 2000      5227
# 2001      6468
# 2002      9715
# 2003     13281
# 2004     17342
# 2005     21394
# 2006     26913
# 2007     30845
# 2008     31502
# 2009     20594
# 2010     26485
# 2011     48548
# 2012    102313
# 2013     98160
# 2014     81068
# 2015      9437
# Name: sellingprice, dtype: int64
